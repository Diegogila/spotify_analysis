# %% [markdown]
# # Spotify Analysis

# %% [markdown]
# #### Import dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Download the dataset and read

# %%
df_spotify = pd.read_csv('../data/spotifydataset.csv')
df_spotify.head()
# Out:
#      artist_name genres  followers  artist_popularity  \
# 0  Ariana Grande    pop   98934105                 89
# 1  Ariana Grande    pop   98934105                 85
# 2  Ariana Grande    pop   98934105                 83
# 3  Ariana Grande    pop   98934105                 80
# 4  Ariana Grande    pop   98934105                 79
#
#                                           artist_url  \
# 0  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 1  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 2  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 3  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 4  https://open.spotify.com/artist/66CXWjxzNUsdJx...
#
#                                           track_name            album_name  \
# 0           we can't be friends (wait for your love)      eternal sunshine
# 1                                    the boy is mine      eternal sunshine
# 2                           intro (end of the world)      eternal sunshine
# ...

# %% [markdown]
# ### Process data

# %% [markdown]
# Drop unnecesary columnns

# %%
df_spotify.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
missing_data_count = df_spotify.isna().sum()
df_spotify.count()
# Out:
# artist_name          1000
# genres                837
# followers            1000
# artist_popularity    1000
# artist_url           1000
# track_name           1000
# album_name           1000
# release_date         1000
# duration_ms          1000
# explicit             1000
# track_popularity     1000
# danceability         1000
# energy               1000
# key                  1000
# loudness             1000
# mode                 1000
# speechiness          1000
# acousticness         1000
# instrumentalness     1000
# liveness             1000
# valence              1000
# tempo                1000
# dtype: int64
